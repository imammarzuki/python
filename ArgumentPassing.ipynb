# %% [markdown]
# Selain dilakukan manipulasi, variable juga sering digunakan untuk passing argument pada fungsi.

# %%
def modify(k):
  k.append(4)
  print('ID k:',id(k))

# %%
m = [1, 2, 3]

# %%
id(m)
# Out:
# 135517178546496

# %%
modify(m)
# Out:
# ID k: 135517178546496

# %%
print(m)
# Out:
# [1, 2, 3, 4]
