# %% [markdown]
# <a href="https://colab.research.google.com/github/imammarzuki/python/blob/main/Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python set adalah unordered collection of unique, immutable objects atau kolesi objek yang unik dan tidak diubah dan tidak ada aturan susunan/urutan. Berikut syntaxnya s = {value1, value2, value3, value4}

# %% [markdown]
# Untuk membuat empty set gunakan constructor set(). Set juga dapat dibuat dari list dengan menggunakan constructor set()

# %%
s = {44, 2, 81, 3, 52, 1}

# %%
s
# Out:
# {1, 2, 3, 44, 52, 81}

# %%
e = set()

# %%
type(e)
# Out:
# set

# %%
 s = set([2, 7, 20, 34, 41, 123])

# %%
s
# Out:
# {2, 7, 20, 34, 41, 123}

# %% [markdown]
# Karena set bersifat unique, maka duplicate item akan dibuang

# %%
t = [1, 1, 3, 3, 7, 7]

# %%
u = set(t)

# %%
u
# Out:
# {1, 3, 7}

# %% [markdown]
# Set juga iterable, namun tidak ada aturan urutan/order

# %%
for x in s:
  print(x)
# Out:
# 2
# 34
# 7
# 41
# 20
# 123

# %% [markdown]
# Untuk menguji apakah suatu item ada dalam set, gunakan operator in atau not in.

# %%
2 in s
# Out:
# True

# %%
2 not is s

# %% [markdown]
# Menambah item pada set, gunakan method add(). Bila kita menambahkan item yang sudah ada, akan diabaikan oleh python (tidak ada error message)

# %%
x = {22, 109}

# %%
x
# Out:
# {22, 109}

# %%
x.add(1)

# %%
x
# Out:
# {1, 22, 109}

# %% [markdown]
# Untuk menambahkan lebih dari satu item pada set, gunakan update() method. Pada contoh dibawah, update

# %%
x = {100, 200, 300}

# %%
x
# Out:
# {100, 200, 300}

# %%
x.update([400, 500])

# %%
x
# Out:
# {100, 200, 300, 400, 500}

# %% [markdown]
# Untuk menghapus gunakan remove(item) methode, pastikan item yang akan dibuang ada, bila tidak akan runtime error. Cara kedua dapat digunakan discard(item) methode, untuk discard tidak terjadi error bila menghapus item yang tidak ada.

# %%
x
# Out:
# {100, 200, 300, 400, 500}

# %%
x.remove(400)

# %%
x
# Out:
# {100, 200, 300, 500}

# %%
x.remove(600)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-97a7b27d562f> in <cell line: 1>()
# ----> 1 x.remove(600)
#
# KeyError: 600

# %%
x.discard(200)

# %%
x
# Out:
# {100, 300, 500}

# %%
x.discard(600)

# %%
x
# Out:
# {100, 300, 500}

# %% [markdown]
# Seperti collection lainnya, set juga dapat dicopy (shallow copy) dengan menggunakan method .copy() atau set() constructor

# %%
k = {3, 5, 9, 12, 2, 99}

# %%
j = k.copy()

# %%
j
# Out:
# {2, 3, 5, 9, 12, 99}

# %%
l = set(j)

# %%
l
# Out:
# {2, 3, 5, 9, 12, 99}
