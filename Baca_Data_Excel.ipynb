# %% [markdown]
# <a href="https://colab.research.google.com/github/imammarzuki/python/blob/main/Baca_Data_Excel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
geo1=pd.read_excel("Untuk Geomap.xlsx")
geo2=pd.read_excel("LatitudeLongitude.xlsx")

# %%
geo1.head()
# Out:
#    No                 Province  Cluster
# 0   1                     Riau        5
# 1   2                West Java        5
# 2   3  Bangka Belitung Islands        5
# 3   4         West Kalimantan         5
# 4   5                   Banten        5

# %%
geo2.head()
# Out:
#    No        Province      Long     Lat
# 0   1            Aceh   95.3169  5.5625
# 1   2  North Sumatera   98.6669  2.6167
# 2   3   West Sumatera  100.3634 -0.3054
# 3   4            Riau  101.4447  0.5333
# 4   5           Jambi  103.6119 -1.6106
