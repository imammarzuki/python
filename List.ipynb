# %% [markdown]
# Isi list adalah object, jadi bisa diisi apa saja, misalnya string dan integer kedalam list.

# %% [markdown]
# List juga dapat dideklarasikan sebagai empty list, kemudian melakukan manipulasi belakangan.

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
a = ["Jeruk", "Apel", "Pisang"]

# %%
a[1]
# Out:
# 'Apel'

# %%
a[1]=4

# %%
a
# Out:
# ['Jeruk', 4, 'Pisang']

# %%
b=[]

# %%
b.append(1.68)

# %%
b
# Out:
# [1.68]

# %%
list("abcd")
# Out:
# ['a', 'b', 'c', 'd']

# %%
c=['Ayam','Sapi','Kuda']

# %%
c
# Out:
# ['Ayam', 'Sapi', 'Kuda']
